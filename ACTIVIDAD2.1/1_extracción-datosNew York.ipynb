# %%
#INSTALAR LIBRERIAS
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn
# !pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
#IMPORTAMOS LIBRERIAS REQUERIDAS
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# CARGA DE ARCHIVO .CSV

# %%
#CONVERTIR EN DATAFRAME
df_csv = pd.read_csv('file.csv')
df_csv
# Out:
#       Periodo  Trimestre Entidad_Federativa     Sexo  \
# 0        2005          1           Nacional  Hombres
# 1        2005          1           Nacional  Mujeres
# 2        2005          1     Aguascalientes  Hombres
# 3        2005          1     Aguascalientes  Mujeres
# 4        2005          1    Baja California  Hombres
# ...       ...        ...                ...      ...
# 4549     2022          1           Veracruz  Mujeres
# 4550     2022          1            Yucat n  Hombres
# 4551     2022          1            Yucat n  Mujeres
# 4552     2022          1          Zacatecas  Hombres
# 4553     2022          1          Zacatecas  Mujeres
#
#      Poblacion_ocupada_en_la_industria_manufacturera Poblaci n_ocupada  \
# 0                                            4384907          26597801
# 1                                            2690296          14843275
# 2                                              56407            246177
# ...

# %% [markdown]
# CARGA ARCHIVO XLSX EXCEL

# %%
#carga desde archivo .xlsx sin indice
df= pd.read_excel('Antigüedad de saldos 17.03.2023.xlsx')
df
# Out:
#     No. CLIENTE                                             NOMBRE  FACTURA  \
# 0          6401                               DONGA HWASUNG MEXICO   F40238
# 1          6401                               DONGA HWASUNG MEXICO   F40353
# 2          4598       PROVEEDORA DE SEGURIDAD INDUSTRIAL DEL GOLFO   F40352
# 3          3930                               INDUSTRIAS LANCERMEX   F40217
# 4          4712                                             HELVEX   F40173
# ..          ...                                                ...      ...
# 159         856  CENTRO DE INVESTIGACION Y DE ESTUDIOS AVANZADO...   F40055
# 160        5926                                 PÚBLICO EN GENERAL  NV00777
# 161        5926                                 PÚBLICO EN GENERAL  NV00778
# 162        5926                                 PÚBLICO EN GENERAL  NV00779
# 163        8429                                  FISHERS QUERETARO   F38248
#
#     FECHA_FACTURA FECHA_VENCIMIENTO  MONTO ADEUDADO
# ...

# %%
#verificamos información del dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 164 entries, 0 to 163
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   No. CLIENTE        164 non-null    object
#  1   NOMBRE             164 non-null    object
#  2   FACTURA            164 non-null    object
#  3   FECHA_FACTURA      164 non-null    datetime64[ns]
#  4   FECHA_VENCIMIENTO  164 non-null    datetime64[ns]
#  5   MONTO ADEUDADO     164 non-null    float64
# dtypes: datetime64[ns](2), float64(1), object(3)
# memory usage: 7.8+ KB

# %% [markdown]
# **FILTROS BASICOS PARA VARIABLES CUALITATIVAS**

# %%
#Filtro por objeto (valor numerico es sin comillas y letras con comillas)
filtro = df[df['No. CLIENTE']== 6401] 
filtro
# Out:
#    No. CLIENTE                NOMBRE FACTURA FECHA_FACTURA FECHA_VENCIMIENTO  \
# 0         6401  DONGA HWASUNG MEXICO  F40238    2023-02-24        2023-03-26
# 1         6401  DONGA HWASUNG MEXICO  F40353    2023-03-14        2023-04-13
# 43        6401  DONGA HWASUNG MEXICO  F40320    2023-03-08        2023-04-07
# 51        6401  DONGA HWASUNG MEXICO  F40253    2023-02-27        2023-03-29
#
#     MONTO ADEUDADO
# 0         97485.94
# 1         97485.94
# 43        10759.00
# 51         9396.00

# %%
#Filtro por objeto
filtro1 = df[df['NOMBRE']== 'INDUSTRIAS LANCERMEX'] 
filtro1
# Out:
#    No. CLIENTE                NOMBRE FACTURA FECHA_FACTURA FECHA_VENCIMIENTO  \
# 3         3930  INDUSTRIAS LANCERMEX  F40217    2023-02-23        2023-03-25
# 12        3930  INDUSTRIAS LANCERMEX  F40114    2023-02-09        2023-03-11
#
#     MONTO ADEUDADO
# 3         52715.74
# 12        35143.82

# %% [markdown]
# loS 2 PUNTOS SON TODAS LAS COLUMNAS Y SI PONEMOS UNA LA SELECCIONAMOS SOLO, LADO IZQUIERDO FILAS Y DERECHO COLUMNAS

# %%
#filtro por filas 
#filtro2= df.iloc[3:10,:  ]     filas consecutivas 
filtro5= df.iloc[ [0] + list(range(10,14)) + [50], [0,1] ]            #filas no consecutivas
filtro5
# Out:
#    No. CLIENTE                                        NOMBRE
# 0         6401                          DONGA HWASUNG MEXICO
# 10        3937                                      RICHALUM
# 11        2046  TRANSPORTADORES Y FABRICACIONES INDUSTRIALES
# 12        3930                          INDUSTRIAS LANCERMEX
# 13        4598  PROVEEDORA DE SEGURIDAD INDUSTRIAL DEL GOLFO
# 50        6396                             DWK LIFE SCIENCES

# %%
#filtro por filas 
#filtro2= df.iloc[3:10,:  ]     filas consecutivas 
filtro2= df.iloc[ [8, 24,100] , : ]            #filas no consecutivas
filtro2
# Out:
#     No. CLIENTE                  NOMBRE FACTURA FECHA_FACTURA  \
# 8           644   CLAVOS NACIONALES C.N  F40340    2023-03-13
# 24         8708       TE.MEX AUTOMOTIVE  F40183    2023-02-20
# 100        3926  PRODUCTOS PENNSYLVANIA  F40357    2023-03-14
#
#     FECHA_VENCIMIENTO  MONTO ADEUDADO
# 8          2023-05-12        45216.34
# 24         2023-03-13        22956.40
# 100        2023-04-13         2756.16

# %%
#filtro por columnas 
filtro3= df.iloc[:, 0:3]           #columnas consecutivas
#filtro4= df.iloc[:, [0, 2, 5]]     #columnas no consecutivas
filtro3
# Out:
#     No. CLIENTE                                             NOMBRE  FACTURA
# 0          6401                               DONGA HWASUNG MEXICO   F40238
# 1          6401                               DONGA HWASUNG MEXICO   F40353
# 2          4598       PROVEEDORA DE SEGURIDAD INDUSTRIAL DEL GOLFO   F40352
# 3          3930                               INDUSTRIAS LANCERMEX   F40217
# 4          4712                                             HELVEX   F40173
# 5          1429                     AUTOLIV STEERING WHEELS MEXICO   F39979
# 6          1429                     AUTOLIV STEERING WHEELS MEXICO   F40319
# 7          5039                                           BUSSMANN   F40082
# 8           644                              CLAVOS NACIONALES C.N   F40340
# 9           644                              CLAVOS NACIONALES C.N   F40351
# 10         3937                                           RICHALUM   F40361
# ...

# %%
#Ver todas las filas 
pd.options.display.max_rows = None

# %%
#Ver todas las columnas 
pd.options.display.max_columns = None

# %%
#convertir archivo filtrado a csv
filtro3.to_csv("NEW YORK.csv")
